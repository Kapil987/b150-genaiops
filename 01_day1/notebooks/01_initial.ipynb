# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(usecwd=True))
# Out:
# True

# %%
print("SAMPLE:", os.getenv("SAMPLE"))
# Out:
# SAMPLE: None

# %%
from openai import OpenAI
import os
client = OpenAI(
    api_key=os.environ.get("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
)

response = client.responses.create(
    # input="Explain GenAIOps in one line.",
    input="What is Mistral?",
    # model="openai/gpt-oss-20b",
    model="llama-3.3-70b-versatile",
)
print(response.output_text)
# Out:
# Mistral can refer to different things, but here are a few possible meanings:
#
# 1. **Mistral (wind)**: The Mistral is a strong, cold, and dry wind that blows from the north or northwest in southern France, particularly in the Rhône Valley and the Mediterranean coast. It's known for its fierce gusts and can have a significant impact on the region's climate and weather.
# 2. **Mistral (poet)**: Frédéric Mistral was a French poet and writer from Provence, who was awarded the Nobel Prize in Literature in 1904. He's best known for his work in promoting the Provençal language and culture.
# 3. **Mistral (aircraft)**: The Mistral is a family of single-engine, turboprop aircraft designed and built by the French company Aérospatiale (now Airbus Helicopters). The aircraft are known for their versatility and are used for various purposes, including training, transport, and aerial work.
# 4. **Mistral (other uses)**: The name "Mistral" is also used in other contexts, such as in shipbuilding (e.g., the Mistral-class amphibious assault ships of the French Navy), in sports (e.g., the Mistral windsurfing class), and in product branding (e.g., Mistral perfume or Mistral wine).
#
# Without more context, it's difficult to determine which meaning of "Mistral" is most relevant. If you have more information or clarification, I'd be happy to try and provide a more specific answer!
