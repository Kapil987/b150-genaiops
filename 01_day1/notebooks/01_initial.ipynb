# %%
import os
from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv(usecwd=True))
# Out:
# True

# %%
print("SAMPLE:", os.getenv("SAMPLE"))
# Out:
# SAMPLE: None

# %%
from openai import OpenAI
import os
client = OpenAI(
    api_key=os.environ.get("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
)

response = client.responses.create(
    # input="Explain GenAIOps in one line.",
    input="What is Mistral?",
    # model="openai/gpt-oss-20b",
    model="llama-3.3-70b-versatile",
)
print(response.output_text)
# Out:
# Mistral can refer to different things, but here are a few possible meanings:
#
# 1. **Mistral (wind)**: The Mistral is a strong, cold, and dry wind that blows from the north or northwest in southern France, particularly in the Rhône Valley and the Mediterranean coast. It's known for its fierce gusts and can have a significant impact on the region's climate and weather.
# 2. **Mistral (poet)**: Frédéric Mistral was a French poet and writer from Provence, who was awarded the Nobel Prize in Literature in 1904. He's best known for his work in promoting the Provençal language and culture.
# 3. **Mistral (aircraft)**: The Mistral is a family of single-engine, turboprop aircraft designed and built by the French company Aérospatiale (now Airbus Helicopters). The aircraft are known for their versatility and are used for various purposes, including training, transport, and aerial work.
# 4. **Mistral (other uses)**: The name "Mistral" is also used in other contexts, such as in shipbuilding (e.g., the Mistral-class amphibious assault ships of the French Navy), in sports (e.g., the Mistral windsurfing class), and in product branding (e.g., Mistral perfume or Mistral wine).
#
# Without more context, it's difficult to determine which meaning of "Mistral" is most relevant. If you have more information or clarification, I'd be happy to try and provide a more specific answer!

# %%
from openai import OpenAI
import os

client = OpenAI(
    api_key=os.environ.get("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
)

with client.responses.stream(
    model="openai/gpt-oss-20b",
    input="write a blog in 200 lines on topic GenAIOps",
) as stream:
    for event in stream:
        if event.type == "response.output_text.delta":
            print(event.delta, end="", flush=True)

    print()  # newline after stream finishes
    final_response = stream.get_final_response()
# Out:
# Generative AI Ops: The Next Frontier in IT Operations.
# As enterprises grapple with digital transformation, the demand for smarter, faster, and autonomous IT operations has never been higher.
# Enter GenAIOps, a paradigm that blends generative AI with traditional AIOps to deliver predictive, self‑healing, and context‑aware services.
# In this blog, we unpack what GenAIOps is, why it matters, and how organizations can start building it.
# What Is AIOps?
# AIOps, or Artificial Intelligence for IT Operations, uses machine learning, data analytics, and automation to reduce complexity in IT.
# It excels at event correlation, anomaly detection, root‑cause analysis, and incident response.
# However, conventional AIOps is largely reactive, relying on rule sets and historical patterns.
# The generative twist changes that.
# What Is GenAIOps?
# GenAIOps adds generative AI—large language models, diffusion models, and multimodal transformers—to the AIOps stack.
# Instead of just detecting a fault, it can generate remediation scripts, craft incident playbooks, and even suggest architectural changes.
# It can simulate scenarios, forecast capacity needs, and produce natural‑language insights for operators.
# The result? A proactive, self‑evolving operations ecosystem.
# Core Capabilities of GenAIOps
# 1️⃣ Generative Remediation
# 2️⃣ Contextual Incident Narratives
# 3️⃣ Predictive Capacity Planning
# 4️⃣ Automated Compliance Auditing
# 5️⃣ Intelligent Service Blueprinting
# How Does It Work?
# Step 1: Data Ingestion
# Collect logs, metrics, traces, tickets, and even chat transcripts from across the stack.
# Step 2: Feature Engineering
# Transform raw telemetry into embeddings that capture semantics and temporal dynamics.
# Step 3: Generative Modeling
# Feed embeddings into a generative backbone (e.g., GPT‑style) fine‑tuned on IT operations corpora.
# Step 4: Inference & Action
# Generate actionable insights, scripts, or dialogues that feed back into monitoring or automation platforms.
# Step 5: Continuous Learning
# Close the loop by feeding outcomes back into the model for reinforcement learning.
# Architectural Patterns
# Micro‑services for Model Serving
# A dedicated inference API exposes the generative engine to Ops dashboards.
# Observability Layer
# Track model confidence, drift, and usage metrics to maintain trust.
# Policy Engine
# Govern generated actions to prevent unsafe or non‑compliant changes.
# Integration Hub
# Plug into CI/CD, ticketing, and chatops for seamless workflows.
# Key Differentiators From Traditional AIOps
# 1️⃣ From Detection to Creation: It writes code, not just flags bugs.
# 2️⃣ Human‑in‑the‑Loop: Operators can refine outputs via natural language.
# 3️⃣ Knowledge Transfer: Models ingest documentation, runbooks, and knowledge bases.
# 4️⃣ Zero‑Touch Automation: Many incidents are resolved before human touch.
# Real‑World Use Cases
# A. Automated Patch Management
# GenAIOps generates patch scripts that are context‑aware and tested against dependency graphs.
# B. Incident Playbook Generation
# When a new error type surfaces, the system drafts a playbook within minutes.
# C. Capacity Forecasting
# It simulates load scenarios and advises on scaling policies.
# D. Security Hardening
# The model identifies missing controls and writes remediation commands.
# E. Cost Optimization
# It predicts cloud spend spikes and suggests rightsizing recommendations.
# Challenges & Mitigation
# 1️⃣ Data Quality
# Ensure telemetry is clean, timestamped, and labeled for supervised signals.
# 2️⃣ Model Bias
# Biases in training data can lead to uneven coverage; perform regular audits.
# 3️⃣ Explainability
# Operators need traceability; integrate LIME or SHAP visualizations.
# 4️⃣ Governance
# Set up clear ownership, compliance checks, and change‑approval pipelines.
# 5️⃣ Skill Gap
# Cross‑disciplinary teams of data scientists, DevOps, and domain experts are essential.
# Roadmap to Adoption
# Phase 1: Proof of Concept
# Pick a low‑risk domain like log correlation and iterate.
# Phase 2: Pilot in Production
# Deploy in a shadow mode, collect feedback, and tune safety nets.
# Phase 3: Scale
# Extend to multi‑cloud, multi‑team, and hybrid environments.
# Phase 4: Institutionalize
# Embed GenAIOps outputs into SLAs, dashboards, and service level agreements.
# Metrics of Success
# Mean Time to Repair (MTTR) drops by 30‑50%.
# Operational cost savings hit 15‑25% annually.
# Human effort shifts from firefighting to strategy.
# Customer satisfaction scores rise due to faster incident resolution.
# Risk mitigation becomes proactive, not reactive.
# Future Outlook
# Generative models will evolve to multi‑modal reasoning—combining code, logs, and human chat in a single context.
# Open‑source toolkits will lower entry barriers for SMEs.
# Regulatory frameworks around AI in critical operations will shape governance models.
# Edge deployment will enable real‑time response for IoT and edge analytics.
# Hybrid AI‑Ops—where generative models collaborate with rule‑based engines—will become mainstream.
# The convergence of DevSecOps and GenAIOps will create a single pipeline for code, security, and operations.
# Bottom Line
# GenAIOps is not just an incremental improvement; it’s a transformative shift.
# By turning data into generative insight, enterprises can unlock agility, resilience, and cost efficiency.
# If you’re ready to move from reactive alerts to proactive solutions, now is the time to invest in GenAIOps.
# Start with a small, well‑defined problem, build a team, and let the generative engine take the lead.
# Remember: the goal is to augment human expertise, not replace it.
# In the era of digital disruption, those who master GenAIOps will set the pace.
# Call to Action
# Explore open‑source GenAIOps frameworks, join community forums, and experiment with pilot projects.
# Share your successes, challenges, and best practices to accelerate collective learning.
# Thank you for reading—here’s to a smarter, more resilient future in IT operations.

# %%
import os
import sys # Unused import
from datetime import datetime

def my_function(name):
    # Rule 1: f-string without placeholders
    print(f"Hello world") 
    
    # Rule 2: Use of 'is' for literal comparison
    if name is "admin": 
        print("Welcome")

    # Rule 3: Missing whitespace/formatting issues
    x = [1,2,3,4] # No space after commas
    
    # Rule 4: Forgotten TODOs (if configured)
    # TODO: fix this later

# Rule 5: No newline at end of file

# %%
import os
import re
from openai import OpenAI

client = OpenAI(
    api_key=os.environ["GROQ_API_KEY"],
    base_url="https://api.groq.com/openai/v1",
)

MODEL = "openai/gpt-oss-20b"
temps = [0.0, 0.2, 0.8, 1.2]

SYSTEM = (
    "You are a strict text completer. "
    "Return only exactly 3 words that continue the sentence. "
    "No explanations, no quotes, no punctuation."
)

USER = "The capital of France is"

def extract_text(resp):
    if getattr(resp, "output_text", None):
        return resp.output_text.strip()
    parts = []
    for item in getattr(resp, "output", []) or []:
        for c in getattr(item, "content", []) or []:
            t = getattr(c, "text", None)
            if t:
                parts.append(t)
    return " ".join(parts).strip()

def normalize_3_words(text):
    words = re.findall(r"[A-Za-z']+", text)
    return " ".join(words[:3]) if words else "[EMPTY]"

for t in temps:
    print(f"\n=== Temperature {t} ===")
    for i in range(5):
        r = client.responses.create(
            model=MODEL,
            temperature=t,
            max_output_tokens=12,
            input=[
                {"role": "system", "content": SYSTEM},
                {"role": "user", "content": USER},
            ],
        )
        raw = extract_text(r)
        clean = normalize_3_words(raw)
        print(f"Run {i+1}: {clean}    (raw: {raw})")
# Out:
# === Temperature 0.0 ===
# Run 1: The user says    (raw: The user says: "The capital of France)
# Run 2: The user says    (raw: The user says: "The capital of France)
# Run 3: The user says    (raw: The user says: "The capital of France)
# Run 4: The user says    (raw: The user says: "The capital of France)
# Run 5: The user says    (raw: The user says: "The capital of France)
#
# === Temperature 0.2 ===
# Run 1: The user says    (raw: The user says: "The capital of France)
# Run 2: The user says    (raw: The user says: "The capital of France)
# Run 3: The user says    (raw: The user says: "The capital of France)
# Run 4: We need to    (raw: We need to respond with exactly 3 words)
# Run 5: We need to    (raw: We need to respond with exactly 3 words)
#
# === Temperature 0.8 ===
# Run 1: We have to    (raw: We have to output exactly 3 words that)
# Run 2: The user says    (raw: The user says: "The capital of France)
# Run 3: We need to    (raw: We need to output exactly 3 words that)
# Run 4: The user says    (raw: The user says: "The capital of France)
# Run 5: We need to    (raw: We need to produce exactly 3 words that)
#
# === Temperature 1.2 ===
# Run 1: We need to    (raw: We need to give exactly 3 words that)
# Run 2: We have a    (raw: We have a user conversation: "The capital)
# Run 3: The instruction Return    (raw: The instruction: Return only exactly 3 words)
# Run 4: We need to    (raw: We need to reply with exactly 3 words)
# Run 5: User asks The    (raw: User asks: "The capital of France is)

# %%
import os
from collections import defaultdict
from openai import OpenAI

client = OpenAI(
    api_key=os.environ["GROQ_API_KEY"],
    base_url="https://api.groq.com/openai/v1",
)

# Pick first available preferred model
preferred = [
    "llama-3.1-8b-instant",
    "llama-3.3-70b-versatile",
    "mixtral-8x7b-32768",
]
available = [m.id for m in client.models.list().data]
model = next((m for m in preferred if m in available), available[0])

temps = [0.0, 0.2, 0.8, 1.2]
runs_per_temp = 5

prompts = {
    "FACTUAL": "What is the capital of France? Answer in 3 words max.",
    "CREATIVE": "Write one vivid line about a dragon flying over Mumbai at sunrise.",
}

print(f"Using model: {model}\n")

for label, prompt in prompts.items():
    print("=" * 70)
    print(f"{label} PROMPT: {prompt}")
    print("=" * 70)

    summary = defaultdict(list)

    for t in temps:
        print(f"\n--- Temperature {t} ---")
        for i in range(runs_per_temp):
            r = client.chat.completions.create(
                model=model,
                temperature=t,
                top_p=1,
                max_tokens=50,
                messages=[{"role": "user", "content": prompt}],
            )
            text = (r.choices[0].message.content or "").strip().replace("\n", " ")
            summary[t].append(text)
            print(f"Run {i+1}: {text}")

    print("\nVariation summary (unique outputs out of 5):")
    for t in temps:
        uniq = len(set(summary[t]))
        print(f"Temp {t}: {uniq}/5 unique")
    print("\n")
# Out:
# Using model: llama-3.1-8b-instant
#
# ======================================================================
# FACTUAL PROMPT: What is the capital of France? Answer in 3 words max.
# ======================================================================
#
# --- Temperature 0.0 ---
# Run 1: Paris is capital.
# Run 2: Paris is capital.
# Run 3: Paris is capital.
# Run 4: Paris is capital.
# Run 5: Paris is capital.
#
# --- Temperature 0.2 ---
# Run 1: Paris is capital.
# Run 2: Paris is capital.
# Run 3: Paris is capital.
# Run 4: Paris is capital.
# Run 5: Paris is capital.
#
# --- Temperature 0.8 ---
# Run 1: Paris is capital.
# Run 2: Paris, France.
# Run 3: Paris is the capital.
# Run 4: Paris is the capital.
# Run 5: Paris, France.
#
# --- Temperature 1.2 ---
# Run 1: Paris is capital.
# Run 2: Paris is capital.
# Run 3: Paris is capital.
# Run 4: Paris is.
# Run 5: Paris is capital.
#
# Variation summary (unique outputs out of 5):
# Temp 0.0: 1/5 unique
# Temp 0.2: 1/5 unique
# Temp 0.8: 3/5 unique
# Temp 1.2: 2/5 unique
#
#
# ======================================================================
# CREATIVE PROMPT: Write one vivid line about a dragon flying over Mumbai at sunrise.
# ======================================================================
#
# --- Temperature 0.0 ---
# Run 1: As the first rays of sunrise danced across the Arabian Sea, a majestic dragon soared above the Mumbai skyline, its scales glinting like a thousand diamonds against the fiery hues of the dawn, its wings beating in powerful, rhythmic strokes that sent wis
# Run 2: As the first rays of sunrise danced across the Mumbai skyline, a majestic dragon burst forth from the darkness, its scales glinting like a thousand diamonds as it soared above the city's towering skyscrapers, its fiery breath illuminating the mist-sh
# Run 3: As the first rays of sunrise danced across the Mumbai skyline, a majestic dragon burst forth from the darkness, its scales glinting like a thousand diamonds as it soared above the city's towering skyscrapers, its fiery breath illuminating the mist-sh
# Run 4: As the first rays of sunrise danced across the Mumbai skyline, a majestic dragon burst forth from the darkness, its scales glinting like a thousand diamonds as it soared above the city's towering skyscrapers, its fiery breath illuminating the mist-sh
# Run 5: As the first rays of sunrise danced across the Mumbai skyline, a majestic dragon burst forth from the darkness, its scales glinting like a thousand diamonds as it soared above the city's towering skyscrapers, its fiery breath illuminating the mist-sh
#
# --- Temperature 0.2 ---
# Run 1: As the first rays of sunrise danced across the Arabian Sea, a majestic dragon burst forth from the mist-shrouded skyscrapers of Mumbai, its scales glinting like a thousand diamonds as it soared into the sky, its fiery breath illuminating
# Run 2: As the first rays of sunrise danced across the Mumbai skyline, a majestic dragon soared overhead, its scales glinting like a thousand diamonds against the fiery hues of the rising sun, its wings beating in powerful, rhythmic strokes that sent wisps of
# Run 3: As the first rays of sunrise danced across the Mumbai skyline, a majestic dragon burst forth from the darkness, its scales glinting like a thousand diamonds as it soared above the city's towering skyscrapers, its fiery breath leaving a trail of golden
# Run 4: As the first light of dawn crept over the Mumbai skyline, a majestic dragon burst forth from the darkness, its scales glinting like a thousand diamonds as it soared above the city's towering skyscrapers, its fiery breath illuminating the mist
# Run 5: As the first rays of sunrise danced across the Arabian Sea, a majestic dragon soared above the Mumbai skyline, its scales glinting like a thousand diamonds against the fiery hues of the dawn, its wings beating in powerful strokes that sent wisps of clouds
#
# --- Temperature 0.8 ---
# Run 1: As the first light of dawn crept over the Mumbai skyline, a majestic dragon soared into the sky, its scales glinting like gold and emeralds as it banked over the glittering waters of the Arabian Sea.
# Run 2: As the first light of dawn crept over the Mumbai skyline, a majestic dragon burst forth from the darkness, its scales glinting like a million rubies in the rising sun, its wings beating powerfully as it soared above the towering skyscrap
# Run 3: "As the first light of dawn crept over the Mumbai skyline, a majestic dragon, its scales glinting like diamonds in the morning haze, spread its wings and soared into the sky, casting a golden glow across the city's concrete canyons
# Run 4: As the crimson sunrise burst over the Mumbai skyline, a majestic dragon soared overhead, its scales glinting like a thousand diamonds against the fiery sky as it left a trail of misty glory in its wake.
# Run 5: As the crimson and golden hues of sunrise danced across the Mumbai skyline, a dragon of molten bronze and emerald scales unfolded its majestic wings, casting a shadow over the bustling streets of Colaba as it soared into the morning sky.
#
# --- Temperature 1.2 ---
# Run 1: As the first rays of dawn kissed the waking metropolis, a molten-hued dragon burst forth from the clouds, its wings beating mighty and slow as it soared above the glittering waters of the Arabian Sea, its claws trailing wisps of morning
# Run 2: As the golden light of sunrise painted the horizon, a majestic dragon soared above the glittering skyscrapers of Mumbai, its scaled wings beating effortlessly as it left a trail of wispy mist through the city's concrete jungle.
# Run 3: As the golden light of sunrise danced across the steel and concrete jungle of Mumbai, a magnificent dragon soared overhead, its wings a kaleidoscope of colors that reflected the shimmering hues of the Arabian Sea, leaving trails of glittering sparks in its wake
# Run 4: As the crimson sunrise burst over the chaotic cityscape of Mumbai, a dragon's mighty wings carved a blazing arc across the sky, its scales glinting like diamonds amidst the golden light.
# Run 5: As the first light of dawn danced across the Arabian Sea, a majestic dragon pierced the pale sky, its scales glinting like molten gold as it soared above the towering skyscrapers of Mumbai, leaving trails of shimmering mist in its wake
#
# Variation summary (unique outputs out of 5):
# Temp 0.0: 2/5 unique
# Temp 0.2: 5/5 unique
# Temp 0.8: 5/5 unique
# Temp 1.2: 5/5 unique

# %% [markdown]
# #### Top p

# %%
import os
from collections import defaultdict
from openai import OpenAI

client = OpenAI(
    api_key=os.environ["GROQ_API_KEY"],
    base_url="https://api.groq.com/openai/v1",
)

preferred = ["llama-3.1-8b-instant", "llama-3.3-70b-versatile", "mixtral-8x7b-32768"]
available = [m.id for m in client.models.list().data]
model = next((m for m in preferred if m in available), available[0])

prompt = "Write one vivid line about a dragon flying over Mumbai at sunrise."
top_ps = [0.2, 0.5, 0.8, 1.0]
runs = 5

print("Model:", model)
summary = defaultdict(list)

for p in top_ps:
    print(f"\n=== top_p={p} (temperature fixed at 0.8) ===")
    for i in range(runs):
        r = client.chat.completions.create(
            model=model,
            temperature=0.8,
            top_p=p,
            max_tokens=50,
            messages=[{"role": "user", "content": prompt}],
        )
        text = (r.choices[0].message.content or "").strip().replace("\n", " ")
        summary[p].append(text)
        print(f"Run {i+1}: {text}")

print("\nUnique outputs:")
for p in top_ps:
    print(f"top_p={p}: {len(set(summary[p]))}/{runs}")
# Out:
# Model: llama-3.1-8b-instant
#
# === top_p=0.2 (temperature fixed at 0.8) ===
# Run 1: As the first rays of sunrise danced across the Arabian Sea, a majestic dragon soared above the Mumbai skyline, its scales glinting like a thousand diamonds against the fiery hues of the dawn, its wings beating in powerful, rhythmic strokes that sent wis
# Run 2: As the first rays of sunrise danced across the Arabian Sea, a majestic dragon soared above the Mumbai skyline, its scales glinting like a thousand diamonds against the fiery hues of the dawn, its wings beating in powerful, rhythmic strokes that sent wis
# Run 3: As the first rays of sunrise danced across the Arabian Sea, a majestic dragon soared above the Mumbai skyline, its scales glinting like a thousand diamonds against the fiery hues of the dawn, its wings beating in powerful, rhythmic strokes that sent wis
# Run 4: As the first rays of sunrise danced across the Mumbai skyline, a majestic dragon burst forth from the darkness, its scales glinting like a thousand diamonds as it soared above the city's towering skyscrapers, its fiery breath illuminating the mist-sh
# Run 5: As the first rays of sunrise danced across the Mumbai skyline, a majestic dragon burst forth from the darkness, its scales glinting like a thousand diamonds as it soared above the city's towering skyscrapers, its fiery breath illuminating the mist-sh
#
# === top_p=0.5 (temperature fixed at 0.8) ===
# Run 1: As the first rays of sunrise danced across the Arabian Sea, a majestic dragon soared above the glittering skyscrapers of Mumbai, its scales glinting like a thousand diamonds against the fiery orange sky.
# Run 2: As the first rays of sunrise danced across the Arabian Sea, a majestic dragon burst forth from the horizon, its scales glinting like a thousand diamonds as it soared above the towering skyscrapers of Mumbai, its fiery breath illuminating the mist-sh
# Run 3: As the first rays of sunrise danced across the Arabian Sea, a majestic dragon burst forth from the horizon, its scales glinting like a thousand diamonds as it soared above the towering skyscrapers of Mumbai, its mighty wings beating in a slow,
# Run 4: As the first rays of sunrise danced across the Mumbai skyline, a majestic dragon burst forth from the horizon, its scales glinting like a thousand diamonds as it soared above the city's towering skyscrapers, its fiery breath illuminating the mist-sh
# Run 5: As the first rays of sunrise danced across the Arabian Sea, a majestic dragon burst forth from the mist-shrouded skyscrapers of Mumbai, its scales glinting like a thousand diamonds as it soared into the dawn sky, its thunderous roar
#
# === top_p=0.8 (temperature fixed at 0.8) ===
# Run 1: As the first light of dawn crept over the towering skyscrapers of Mumbai, a majestic dragon soared overhead, its scales glinting like a thousand tiny diamonds against the fiery orange horizon, its wings beating powerful and slow as it left a trail
# Run 2: As the first rays of sunlight danced across the Arabian Sea, a magnificent dragon soared above the Mumbai skyline, its scales glinting like a thousand diamonds against the fiery hues of dawn, its wings beating in a slow, majestic rhythm that sent the city
# Run 3: As the first rays of sunrise danced across the Arabian Sea, a mighty dragon soared above the Mumbai skyline, its iridescent scales glinting like a thousand diamonds against the fiery orange hue of the dawn, its wings beating powerful and slow as it
# Run 4: As the golden light of dawn burst over the Mumbai skyline, a majestic dragon soared overhead, its iridescent scales glimmering like a thousand diamonds scattered across the horizon as it left a trail of wispy clouds in its wake.
# Run 5: As the first rays of sunrise danced across the Arabian Sea, a magnificent dragon soared overhead, its scales glinting like diamonds against the vibrant hues of Mumbai's awakening skyline.
#
# === top_p=1.0 (temperature fixed at 0.8) ===
# Run 1: As the pink-tinged sun burst over the Indian Ocean, a magnificent dragon soared above the towering skyscrapers of Mumbai, its iridescent scales glinting like a thousand diamonds scattered across the horizon.
# Run 2: "As the city of Mumbai slowly awakened to the warmth of sunrise, a magnificent dragon soared overhead, its scales glinting like a thousand diamonds scattered across the sky as it left a trail of glittering mist in its wake, the Victoria Terminus's
# Run 3: As the first rays of sunlight danced across the Arabian Sea, a majestic dragon burst forth from the misty dawn, its scales glinting like polished rubies against the vibrant hues of Mumbai's awakening skyline.
# Run 4: As dawn broke over the Arabian Sea, a magnificent dragon unfolded its iridescent wings, casting a kaleidoscope of colors across the Mumbai skyline as it soared into the rising sun.
# Run 5: As the first light of dawn touched the skyscrapers of Mumbai, a dragon's majestic form burst across the horizon, its scales glinting like polished rubies as it soared over the bustling city, its fiery breath leaving a trail of glittering
#
# Unique outputs:
# top_p=0.2: 2/5
# top_p=0.5: 5/5
# top_p=0.8: 5/5
# top_p=1.0: 5/5
