# %% [markdown]
# ### Python Basics Assignment Solutions

# %% [markdown]
# ##### Q1. Syntax and Semantics - Write a script that prints your name and age using variables, and add one comment describing the script.

# %%
name = 'Karan'
age = 28
# Store and print basic personal details
print(f'My name is {name} and I am {age} years old.')

# %% [markdown]
# ##### Q2. Syntax Debugging - Correct and run this code:
# print('Python Basics')  value = 10  print(Value)

# %%
print('Python Basics')
value = 10
print(value)
# Out:
# Python Basics
# 10

# %% [markdown]
# ##### Q3. Variable Naming - Create one snake_case, one camelCase, one ALL_CAPS variable, and two invalid names as comments with reason.

# %%
student_name = 'Asha'
rollNumber = 21
MAX_ATTEMPTS = 3
# 2student = 'invalid: starts with digit'
# user-name = 'invalid: hyphen not allowed'
print(student_name, rollNumber, MAX_ATTEMPTS)

# %% [markdown]
# ##### Q4. Basic Data Types - Create int, float, str, and bool variables, then print each value with type().

# %%
a = 10
b = 3.14
c = 'Hello'
d = True
print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))

# %% [markdown]
# ##### Q5. Type Conversion - Convert the string 125 to int and float, then print all values with their types.

# %%
s = '125'
i = int(s)
f = float(i)
print(s, type(s))
print(i, type(i))
print(f, type(f))

# %% [markdown]
# ##### Q6. Collection Types - Create list, tuple, set, and dictionary examples for student data and print them.

# %%
student_list = ['Asha', 21, 'Data Science']
student_tuple = ('Asha', 21, 'Data Science')
student_set = {'Asha', 21, 'Data Science'}
student_dict = {'name':'Asha','age':21,'course':'Data Science'}
print(student_list)
print(student_tuple)
print(student_set)
print(student_dict)

# %% [markdown]
# ##### Q7. Arithmetic Operators - With a=17 and b=5, print +, -, *, /, //, %, and ** results.

# %%
a = 17
b = 5
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a // b)
print(a % b)
print(a ** b)

# %% [markdown]
# ##### Q8. Comparison Operators - Take two numbers and print results of ==, !=, >, <, >=, <=.

# %%
x = 14
y = 9
print(x == y)
print(x != y)
print(x > y)
print(x < y)
print(x >= y)
print(x <= y)

# %% [markdown]
# ##### Q9. Logical Operators - Using three boolean variables, evaluate expressions with and, or, and not.

# %%
p = True
q = False
r = True
print(p and q)
print(p or q)
print(not r)
print((p and r) or q)

# %% [markdown]
# ##### Q10. Mixed Operators - For x=12 and y=7, print (x+y)*2, x%y, x>y and y<10, and not(x==y).

# %%
x = 12
y = 7
print((x + y) * 2)
print(x % y)
print(x > y and y < 10)
print(not (x == y))
