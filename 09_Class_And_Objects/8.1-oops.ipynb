# %% [markdown]
# ####  Classes and Objects
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to design applications and computer programs. OOP allows for modeling real-world scenarios using classes and objects. This lesson covers the basics of creating classes and objects, including instance variables and methods.

# %% [markdown]
# **Imagine a Blueprint:**
#
# Think of the `class Car:` line as creating a **blueprint** for making cars. This blueprint says: "Hey, if you want to build a car, here's the general idea of what a car is."
#
# * **`class Car:`**: This is like drawing the basic shape and listing the common features that all cars will have. In this simple blueprint, we haven't listed any specific features yet (that's what `pass` means for now - "we'll add details later").
#
# **Creating Actual Cars (Objects):**
#
# Now, when you write:
#
# * **`audi = Car()`**: This is like taking the "Car" blueprint and actually building a specific car – an **Audi**. `audi` is now a real, individual car based on the general "Car" blueprint. We call this real car an **object** or an **instance** of the `Car` class.
#
# * **`bmw = Car()`**: Similarly, this is like using the same "Car" blueprint to build another specific car – a **BMW**. `bmw` is another individual **object** of the `Car` class.
#
# **Checking What They Are:**
#
# * **`print(type(audi))`**: This line is like asking, "What kind of thing is `audi`?" Python will tell you that `audi` is an object (an instance) of the `Car` class. The output will be something like `<class '__main__.Car'>`. This confirms that you successfully used the `Car` blueprint to create the `audi` object.
#
# **In Simple Terms:**
#
# * **Class (`Car`)**: Think of it as a **recipe** or a **mold** for creating something. It defines the general structure and characteristics.
# * **Object (`audi`, `bmw`)**: Think of it as the **actual thing** you created using the recipe or the mold. Each object is a specific instance of the class.

# %% [markdown]
# ![Insert Alt Text Here](images/1.car_class_pyy.png)

# %%
2
# Out:
# 2

# %%
### A class is a blue print for creating objects. Attributes,methods
class Car:
    pass

audi=Car() # instance/object of class car
bmw=Car()   # # instance/object of class car

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)
# Out:
# <__main__.Car object at 0x00000204B5E39FD0>
# <__main__.Car object at 0x00000204B48D5BD0>

# %%
# defining attributes like below is not a better way, will learn later how to define attributes using constructors etc
audi.windows=4

print(audi.windows)
# Out:
# 4

# %%
tata=Car()
tata.doors=4

# the below shows error becuase we have not defined windows for tata
# print(tata.windows)
print(tata.doors)
# Out:
# 4

# %%
# when you purchase a car you get inbuilt features right like, AC, Power driver, Power windows, music system etc
# Note doors which we have defined above is also available in dir(tata)
# Note: there is an attribute named as __init__ in the below
dir(tata)[-1]
# print(mylist[-1])
# Out:
# 'doors'

# %% [markdown]
# [Is it true that Apple uses Samsung's tech on it's iPhone product?](https://r1.community.samsung.com/t5/others/is-it-true-that-apple-uses-samsung-s-tech-on-it-s-iphone-product/td-p/32413049)

# %% [markdown]
# ![Insert Alt Text Here](images/5.lego_car.png)

# %% [markdown]
# Imagine you're ordering a custom-built LEGO car from a catalog (the class). The catalog shows the general model, but you want to specify certain things *when your car is being built*, like its color, the type of wheels, or maybe even a special spoiler.
#
# **Think of it this way:**
#
# * **Without a constructor:** Creating an object is like getting a blank LEGO car base. You'd have to manually add each wheel, the windshield, the doors, and decide on the color *after* you've got the basic base. This can be error-prone and less organized.
#
# * **With a constructor (`__init__`)**: Creating an object is like ordering your LEGO car with specific instructions. You say, "Build me a car that's an Audi A4 and silver." The constructor ensures that when the car is built (the object is created), it already has these properties set up correctly from the start.
#
# **In summary, the constructor (`__init__`) is crucial for:**
#
# * **Initializing the state (attributes) of an object.**
# * **Ensuring objects are created in a usable state.**
# * **Simplifying object creation by setting multiple attributes at once.**
# * **Performing necessary setup operations when an object is instantiated.**
#
# `self` refers to the particular Car object that is currently being initialized

# %% [markdown]
# #### Attributes and Method in class

# %%
class Car:
    # Attributes (Data)
    def __init__(self, brand, color): # brand = Audi, color = Silver
        self.brand = brand # Attributes
        self.color = color # Attributes
        print('constructor was called')

    # Method (Behavior)
    def drive(self):
        print(f"The {self.color} {self.brand} is driving!")

# def abc(var1,var2):
#     print('the var value is',var1,var2)

# Creating instances with specific data
audi = Car("Audi", "Silver")
bmw = Car("BMW", "Black")

audi.drive('afjsd') # Output: The Silver Audi is driving! , 
bmw.drive()
# the audi dot will indicate python plugin to provide suggestions, 
# drive() --> hover mouse on this, why def drive() -> None , takes no input even when self is given ?
# Out:
# constructor was called
# constructor was called
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 19
#      16 audi = Car("Audi", "Silver")
#      17 bmw = Car("BMW", "Black")
# ---> 19 audi.drive('afjsd') # Output: The Silver Audi is driving! ,
#      20 bmw.drive()
#      21 # the audi dot will indicate python plugin to provide suggestions,
#      22 # drive() --> hover mouse on this, why def drive() -> None , takes no input even when self is given ?
#
# TypeError: Car.drive() takes 1 positional argument but 2 were given

# %% [markdown]
# #### Why does it say it takes no inputs?
# This is the "magic" of Python classes.
#
# When you define a method, you must include self as the first parameter so the method can access the object's own data (like self.color). However, when you call the method, Python automatically passes the object in for you.
#
# At Definition: def drive(self): (Requires 1 argument)
#
# At Call time: audi.drive() (You pass 0 arguments)
#
# Behind the scenes, audi.drive() is converted by Python into Car.drive(audi). Because Python handles this automatically, VS Code telling you that as the programmer, you don't need to pass any additional information into the parentheses.

# %% [markdown]
# #### Dog class example, The Constructor

# %%
### Instance Variable and Methods
class Dog:
    ## constructor is used to creat and object of the class
    # name1 = buddy , age1 = 3
    def __init__(self,name1,age1): # you can use other than self as well, but self is kind of a convention
        # print('i have been called')

        # the below are instance variables
        self.name=name1
        self.age=age1
        print(f"name: {self.name},age: {self.age}")

## the below are instances or objects of class

# dogtest=Dog("tommy",4) # error

dog1=Dog("Buddy1",3) # creating object of this class
# dog3=Dog("Buddy3",3) # creating object of this class
# dog4=Dog("Buddy4",3) # creating object of this class
print(dog1)
print(dog1.name)
print(dog1.age)

# dir(dog1)
# dir(dogtest)
# dir(dog4)
# Out:
# name: Buddy1,age: 3
# <__main__.Dog object at 0x00000204B5E3B620>
# Buddy1
# 3

# %%
dog2=Dog("Lucy",4)
print(dog2.name)
print(dog2.age)
# Out:
# Lucy
# 4

# %%
## Define a class with instance methods
class Dog:
    def __init__(self,name,age): # Attributes: name and age. These are characteristics or 
                                # properties that describe a Dog object.
    # Variables: self.name and self.age. These are instance variables that hold the specific values for the name and 
    # age attributes of a particular Dog object. The self keyword is used to refer to the instance of the class.
        self.name=name
        self.age=age
    
    # the below is instance method
    def bark(self):
        print(f"{self.name} says woof")


dog1=Dog("Buddy",3)

# print(dog1.age)
# print(dog1.name)
# dog1.bark()

dog2=Dog("Lucy",4)
dog2.bark()
# Out:
# Lucy says woof

# %%
class Calculation:
    def __init__(tt,num1,num2): # Attributes: name and age. These are characteristics or 
                                # properties that describe a Dog object.
    # Variables: self.name and self.age. These are instance variables that hold the specific values for the name and 
    # age attributes of a particular Dog object. The self keyword is used to refer to the instance of the class.
        tt.num1=num1
        tt.num2=num2
    
    # the below is instance method
    def add1(tt):
        print(f"result of addition is :",tt.num1+tt.num2)

demo1=Calculation(10,20)
demo1.add1()
# Out:
# result of addition is : 30

# %% [markdown]
# #### Conclusion
# Object-Oriented Programming (OOP) allows you to model real-world scenarios using classes and objects. In this lesson, you learned how to create classes and objects, define instance variables and methods, and use them to perform various operations. Understanding these concepts is fundamental to writing effective and maintainable Python code.
